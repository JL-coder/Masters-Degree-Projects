# %% [markdown]
# ### Team 3 Authors: Joshua Levy, Ryan Killea, Muralidhar Koripalli, Kartik Nautiyal

# %% [markdown]
# ### Data Processing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel("CompiledData502_2.xlsx")
df.head()
# Out:
#   City Name  Percent Cases Total  Percent Cases Last 14 Days  Population  \
# 0  Abington             0.015283                    0.000370       16227
# 1     Acton             0.007389                    0.000042       23549
# 2  Acushnet             0.009831                    0.000095       10477
# 3     Adams             0.004275                    0.000000        8187
# 4    Agawam             0.017546                    0.000659       28839
#
#    Median annual household income 2019 Bond Rating  Residential Tax Rating  \
# 0                           91643              NaN                   17.39
# 1                          133713              Aaa                   19.37
# 2                           69402              NaN                   14.18
# 3                           49777              NaN                   21.39
# 4                           61919              Aa2                   16.65
#
#    Open Space Tax Rating  Commercial Tax Rating  Industrial Tax Rating  ...  \
# 0                    0.0                  17.39                  17.39  ...
# 1                    0.0                  19.37                  19.37  ...
# 2                    0.0                  18.20                  18.20  ...
# 3                    0.0                  25.40                  25.40  ...
# 4                    0.0                  31.92                  31.92  ...
#
#    Commercial Levy   Industrial Levy  Personal Property Levy   Labor Force  \
# 0        3345457.47        327005.04                750914.11         9393
# 1        6305363.19       1775940.39               1486652.19        13038
# 2         591499.22        446970.52               1035493.59         6331
# 3         874478.44        737392.18                655712.86         4126
# 4        8391324.79       6125764.97               9121915.66        16548
#
#    Employed  Unemployed  EQV Per Capita  Total Revenues  Meals Tax Rate  \
# 0      9107         286          116629     26460426421          0.0075
# 1     12776         262          182870        51330190          0.0075
# 2      6111         220          105534        93740261             NaN
# 3      3959         167           60722        28604740          0.0075
# 4     16060         488          102260        16373818          0.0075
#
#    Marijuana Tax Rate
# 0                0.03
# 1                 NaN
# 2                 NaN
# 3                0.03
# 4                 NaN
#
# [5 rows x 28 columns]

# %%
#Dataset contains NaN values. Change them to zeros.
df = df.fillna(0)
df.head()
# Out:
#   City Name  Percent Cases Total  Percent Cases Last 14 Days  Population  \
# 0  Abington             0.015283                    0.000370       16227
# 1     Acton             0.007389                    0.000042       23549
# 2  Acushnet             0.009831                    0.000095       10477
# 3     Adams             0.004275                    0.000000        8187
# 4    Agawam             0.017546                    0.000659       28839
#
#    Median annual household income 2019 Bond Rating  Residential Tax Rating  \
# 0                           91643                0                   17.39
# 1                          133713              Aaa                   19.37
# 2                           69402                0                   14.18
# 3                           49777                0                   21.39
# 4                           61919              Aa2                   16.65
#
#    Open Space Tax Rating  Commercial Tax Rating  Industrial Tax Rating  ...  \
# 0                    0.0                  17.39                  17.39  ...
# 1                    0.0                  19.37                  19.37  ...
# 2                    0.0                  18.20                  18.20  ...
# 3                    0.0                  25.40                  25.40  ...
# 4                    0.0                  31.92                  31.92  ...
#
#    Commercial Levy   Industrial Levy  Personal Property Levy   Labor Force  \
# 0        3345457.47        327005.04                750914.11         9393
# 1        6305363.19       1775940.39               1486652.19        13038
# 2         591499.22        446970.52               1035493.59         6331
# 3         874478.44        737392.18                655712.86         4126
# 4        8391324.79       6125764.97               9121915.66        16548
#
#    Employed  Unemployed  EQV Per Capita  Total Revenues  Meals Tax Rate  \
# 0      9107         286          116629     26460426421          0.0075
# 1     12776         262          182870        51330190          0.0075
# 2      6111         220          105534        93740261          0.0000
# 3      3959         167           60722        28604740          0.0075
# 4     16060         488          102260        16373818          0.0075
#
#    Marijuana Tax Rate
# 0                0.03
# 1                0.00
# 2                0.00
# 3                0.03
# 4                0.00
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   City Name                       351 non-null    object
#  1   Percent Cases Total             351 non-null    float64
#  2   Percent Cases Last 14 Days      351 non-null    float64
#  3   Population                      351 non-null    int64
#  4   Median annual household income  351 non-null    int64
#  5   2019 Bond Rating                351 non-null    object
#  6   Residential Tax Rating          351 non-null    float64
#  7   Open Space Tax Rating           351 non-null    float64
#  8   Commercial Tax Rating           351 non-null    float64
#  9   Industrial Tax Rating           351 non-null    float64
#  10  Personal Property Tax Rating    351 non-null    float64
#  11  Residential APV                 351 non-null    int64
#  12  Open Space APV                  351 non-null    int64
#  13  Commercial APV                  351 non-null    int64
#  14  Industrial APV                  351 non-null    int64
#  15  Personal Property APV           351 non-null    int64
#  16  Residential Levy                351 non-null    float64
#  17  Open Space Levy                 351 non-null    float64
#  18  Commercial Levy                 351 non-null    float64
#  19  Industrial Levy                 351 non-null    float64
#  20  Personal Property Levy          351 non-null    float64
#  21  Labor Force                     351 non-null    int64
#  22  Employed                        351 non-null    int64
#  23  Unemployed                      351 non-null    int64
#  24  EQV Per Capita                  351 non-null    int64
#  25  Total Revenues                  351 non-null    int64
#  26  Meals Tax Rate                  351 non-null    float64
#  27  Marijuana Tax Rate              351 non-null    float64
# dtypes: float64(14), int64(12), object(2)
# memory usage: 76.9+ KB

# %%
#City Name and 2019 Bond Rating are strings. To process bond rating need to be numeric.
df['2019 Bond Rating'].unique()
# Out:
# array([0, 'Aaa', 'Aa2', 'Aa1', 'A1', 'Aa3', 'A3', 'A2', 'Baa1'],
#       dtype=object)

# %%
#Bond ratings are ordinal with best to worst: AAA, AA1, AA2, AA3, A1, A2, A3, BAA1, 0
#Not sure if it makes more sense for zero to be 0 or 9...Changed to 9 for the time being
scale_mapper = {"Aaa":1, "Aa1":2, "Aa2":3, "Aa3":4, "A1":5, "A2":6, "A3":7, "Baa1":8, 0:9}
df["Scaled 2019 Bond Rating"] = df["2019 Bond Rating"].replace(scale_mapper)
df.head()
# Out:
#   City Name  Percent Cases Total  Percent Cases Last 14 Days  Population  \
# 0  Abington             0.015283                    0.000370       16227
# 1     Acton             0.007389                    0.000042       23549
# 2  Acushnet             0.009831                    0.000095       10477
# 3     Adams             0.004275                    0.000000        8187
# 4    Agawam             0.017546                    0.000659       28839
#
#    Median annual household income 2019 Bond Rating  Residential Tax Rating  \
# 0                           91643                0                   17.39
# 1                          133713              Aaa                   19.37
# 2                           69402                0                   14.18
# 3                           49777                0                   21.39
# 4                           61919              Aa2                   16.65
#
#    Open Space Tax Rating  Commercial Tax Rating  Industrial Tax Rating  ...  \
# 0                    0.0                  17.39                  17.39  ...
# 1                    0.0                  19.37                  19.37  ...
# 2                    0.0                  18.20                  18.20  ...
# 3                    0.0                  25.40                  25.40  ...
# 4                    0.0                  31.92                  31.92  ...
#
#    Industrial Levy  Personal Property Levy   Labor Force  Employed  \
# 0        327005.04                750914.11         9393      9107
# 1       1775940.39               1486652.19        13038     12776
# 2        446970.52               1035493.59         6331      6111
# 3        737392.18                655712.86         4126      3959
# 4       6125764.97               9121915.66        16548     16060
#
#    Unemployed  EQV Per Capita  Total Revenues  Meals Tax Rate  \
# 0         286          116629     26460426421          0.0075
# 1         262          182870        51330190          0.0075
# 2         220          105534        93740261          0.0000
# 3         167           60722        28604740          0.0075
# 4         488          102260        16373818          0.0075
#
#    Marijuana Tax Rate  Scaled 2019 Bond Rating
# 0                0.03                        9
# 1                0.00                        1
# 2                0.00                        9
# 3                0.03                        9
# 4                0.00                        3
#
# [5 rows x 29 columns]

# %%
#We don't need the non-numeric column anymore
del df['2019 Bond Rating']

# %%
#Check it was done properly
df.head()
# Out:
#   City Name  Percent Cases Total  Percent Cases Last 14 Days  Population  \
# 0  Abington             0.015283                    0.000370       16227
# 1     Acton             0.007389                    0.000042       23549
# 2  Acushnet             0.009831                    0.000095       10477
# 3     Adams             0.004275                    0.000000        8187
# 4    Agawam             0.017546                    0.000659       28839
#
#    Median annual household income  Residential Tax Rating  \
# 0                           91643                   17.39
# 1                          133713                   19.37
# 2                           69402                   14.18
# 3                           49777                   21.39
# 4                           61919                   16.65
#
#    Open Space Tax Rating  Commercial Tax Rating  Industrial Tax Rating  \
# 0                    0.0                  17.39                  17.39
# 1                    0.0                  19.37                  19.37
# 2                    0.0                  18.20                  18.20
# 3                    0.0                  25.40                  25.40
# 4                    0.0                  31.92                  31.92
#
#    Personal Property Tax Rating  ...  Industrial Levy  \
# 0                         17.39  ...        327005.04
# 1                         19.37  ...       1775940.39
# 2                         18.20  ...        446970.52
# 3                         25.40  ...        737392.18
# 4                         31.92  ...       6125764.97
#
#    Personal Property Levy   Labor Force  Employed  Unemployed  EQV Per Capita  \
# 0                750914.11         9393      9107         286          116629
# 1               1486652.19        13038     12776         262          182870
# 2               1035493.59         6331      6111         220          105534
# 3                655712.86         4126      3959         167           60722
# 4               9121915.66        16548     16060         488          102260
#
#    Total Revenues  Meals Tax Rate  Marijuana Tax Rate  Scaled 2019 Bond Rating
# 0     26460426421          0.0075                0.03                        9
# 1        51330190          0.0075                0.00                        1
# 2        93740261          0.0000                0.00                        9
# 3        28604740          0.0075                0.03                        9
# 4        16373818          0.0075                0.00                        3
#
# [5 rows x 28 columns]

# %% [markdown]
# ### K-Means Model Creation

# %%
#Create Model to Predict Percent Cases Total and another for Percent Cases Last 14 Days

#Main dependent variables to worry about:
#Median Household Income
#Bond Rating
#Population
#DOR Income per Capita
#Tax Ratings
#Tax Levy by Class
#Employment Statistics
#Total General Fund Revenues
#Marijuana and Meals Tax

#Start by creating a K-means model for Predicting Percent Cases Total/Last 14 Days
#Use all of the variables in x
x = df.iloc[:, 1:29]
#y = df.iloc[:, 1]

#Scale data since some numbers are extremly large
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)
x = pd.DataFrame(x)
x
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.649741  0.105272 -0.075842  0.206076  0.596365 -0.231833 -0.144494
# 1   -0.246167 -0.602971  0.101557  1.687325  1.095146 -0.231833  0.143483
# 2    0.030994 -0.488319 -0.215154 -0.577010 -0.212264 -0.231833 -0.026685
# 3   -0.599542 -0.694863 -0.270637 -1.267989  1.604003 -0.231833  1.020501
# 4    0.906508  0.730822  0.229724 -0.840480  0.409952 -0.231833  1.968787
# ..        ...       ...       ...       ...       ...       ...       ...
# 346  0.854808  0.289876  0.489353 -0.087533 -1.391201 -0.231833  0.776158
# 347  2.341134  1.073168  4.008740 -1.405587  0.750030 -0.231833  2.402205
# 348 -1.084709 -0.694863 -0.440210 -0.379909  0.321784 -0.231833 -0.303026
# 349  1.077333  2.115968 -0.189206  0.762416 -0.227379 -0.231833 -0.020867
# 350 -0.489875 -0.602650  0.099570 -0.804039 -1.240055 -0.231833 -1.204770
#
#            7         8         9   ...        17        18        19  \
# 0   -0.144494 -0.144025 -0.156192  ... -0.289961 -0.164765 -0.058256
# 1    0.143483  0.144108  0.164837  ... -0.084381 -0.085913  0.094684
# 2   -0.026685 -0.026153 -0.268463  ... -0.272940 -0.134265 -0.186735
# 3    1.020501  1.021606 -0.370948  ... -0.231734 -0.174968 -0.279254
# 4    1.968787  1.970410 -0.082325  ...  0.532787  0.732393  0.241959
# ..        ...       ...       ...  ...       ...       ...       ...
# 346  0.776158  0.777129  0.425308  ...  2.530866  0.654904  0.557448
# 347  2.402205  2.404066  1.081177  ...  2.252736  2.749315  3.487771
# 348 -0.303026 -0.302644 -0.410727  ... -0.335319 -0.237632 -0.422459
# 349 -0.020867 -0.026153 -0.164616  ... -0.233793 -0.129669 -0.155181
# 350 -1.204770 -1.204881  0.392395  ... -0.286599 -0.109916  0.039088
#
#            20        21        22         23        24        25        26
# 0   -0.059326 -0.015334 -0.309061  18.527095  0.653322  1.035123  0.962163
# 1    0.098508 -0.054801 -0.104990  -0.069864  0.653322 -0.968525 -1.803195
# 2   -0.188209 -0.123868 -0.343242  -0.039999 -1.530639 -0.968525  0.962163
# 3   -0.280785 -0.211025 -0.481296  -0.085867  0.653322  1.035123  0.962163
# 4    0.239780  0.316846 -0.353329  -0.094480  0.653322 -0.968525 -1.111855
# ..        ...       ...       ...        ...       ...       ...       ...
# 346  0.559492  0.459914 -0.125126  -0.068436  0.653322 -0.968525 -1.457525
# 347  3.462370  4.337545 -0.464371  -0.003065  0.653322 -0.968525 -0.766185
# 348 -0.421154 -0.457693 -0.232755   0.355635  0.653322  1.035123  0.962163
# 349 -0.154311 -0.183069 -0.110021  -0.102996 -1.530639 -0.968525 -1.111855
# 350  0.032862  0.275735  0.091040  -0.075742  0.653322 -0.968525  0.962163
#
# [351 rows x 27 columns]

# %%
#Use this in anaconda installer to get it working:
#conda install -c conda-forge yellowbrick

from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,15)).fit(x)
visualizer.show()

#Based off the graph the optimal number of clusters is 4
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
from sklearn.cluster import KMeans
#K-means++ uses seeding technique for centroid initialization better than random initialization
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=1).fit(x)

# %%
#Check prediction on x data - cluster labels
y_kmeans = kmeans.predict(x)
y_kmeans = pd.DataFrame(y_kmeans)
y_kmeans
#prediction = pd.DataFrame(y_kmeans)
#prediction.head(10)
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    3
# ..  ..
# 346  3
# 347  3
# 348  0
# 349  0
# 350  0
#
# [351 rows x 1 columns]

# %%
#Cluster size for each of the 3 clusters
from collections import Counter
Counter(kmeans.labels_)
# Out:
# Counter({0: 271, 3: 78, 2: 1, 1: 1})

# %%
#Centers for the kmeans clusters
center = kmeans.cluster_centers_
center
# Out:
# array([[-2.99445995e-01, -1.25299149e-01, -2.24536945e-01,
#          7.59091277e-02,  1.35526240e-02,  1.47951683e-02,
#         -3.97209463e-01, -3.97209463e-01, -3.97088808e-01,
#         -1.48672603e-01, -1.56381675e-02, -1.04132793e-01,
#         -1.56797414e-01, -1.42438931e-01, -1.94722165e-01,
#         -2.59402220e-02, -1.10290265e-01, -2.42114926e-01,
#         -1.63766427e-01, -2.15795774e-01, -2.15038412e-01,
#         -2.37244980e-01,  7.20736705e-02,  1.88419693e-02,
#         -8.80968348e-02,  1.97441711e-02,  1.66230072e-01],
#        [-2.18105273e-02, -4.80374615e-02,  2.20584784e+00,
#          1.18123842e-01, -2.28799824e+00, -2.31832725e-01,
#         -6.79722217e-01, -6.79722217e-01, -6.79546610e-01,
#          4.02649916e+00, -1.54537895e-01,  3.59054238e+00,
#          1.75429193e+01,  4.00260300e+00,  1.80273199e+00,
#         -1.39249666e-01,  1.93994221e+00,  1.50548731e+01,
#          2.09881109e+00,  2.60206163e+00,  2.62828714e+00,
#          1.50907804e+00,  4.35849045e-01, -6.52736132e-03,
#          6.53321719e-01,  1.03512257e+00, -1.80319454e+00],
#        [ 1.46713094e+00,  7.32346868e-01,  1.56945305e+01,
#         -8.36888760e-01, -1.12921469e+00, -2.31832725e-01,
#          9.62324128e-01,  9.62324128e-01,  9.63397566e-01,
#          1.58883809e+01, -1.54537895e-01,  1.81293088e+01,
#          2.46288389e+00,  1.75528594e+01,  1.51326061e+01,
#         -1.39249666e-01,  1.83722597e+01,  3.94263503e+00,
#          1.75561214e+01,  1.61528039e+01,  1.61775569e+01,
#          1.46450059e+01, -5.35289452e-03, -8.58971321e-02,
#          6.53321719e-01,  1.03512257e+00, -1.80319454e+00],
#        [ 1.02185313e+00,  4.26561025e-01,  5.50629918e-01,
#         -2.54520624e-01, -3.27625846e-03, -4.54592969e-02,
#          1.37642516e+00,  1.37642516e+00,  1.37598995e+00,
#          2.61223016e-01,  5.82951177e-02,  8.33350732e-02,
#          2.88285847e-01,  2.18531896e-01,  4.59414984e-01,
#          9.36961472e-02,  1.22775127e-01,  5.97636368e-01,
#          3.16997044e-01,  5.09304989e-01,  5.06020073e-01,
#          6.17170585e-01, -2.55928985e-01, -6.42788359e-02,
#          2.89328190e-01, -9.51399425e-02, -5.31307185e-01]])

# %%
# because the clusters are super high dimensional we have to use PCA to project into 2 dimensions
# I have no idea what the 0/1 labels are here, but this does appear to be the data at least at a high level?
# the 0/1 could be positive/negative as PCA typically is centered around 0...
# regardless we see a high number of outliers
from sklearn.decomposition import PCA
import seaborn as sns
#Want explained variance between %95-99 generally. Lower n_components to 0.95
pca = PCA(n_components=2)
pca.fit(x)
points = pca.transform(x)
centers = pca.transform(center)
plot_data = {"points":{"x": points[0], "y": points[1]}, "centers":{"x": centers[0], "y": centers[1]}}
sns.scatterplot(x="x", y="y", data={"x": points[:,0], "y": points[:,1]}).set(title = "PCA Transformed Y-Variables")
# Out:
# [Text(0.5, 1.0, 'PCA Transformed Y-Variables')]

# %%
sns.scatterplot(data=centers)
# Out:
# <AxesSubplot:>

# %%
# now what I originally thought we would be doing:
# use k-means on only the 1st 2 variables to determine how cities did vs covid in general
x2 = df.iloc[:, 1:3]
sns.scatterplot(x="Percent Cases Total", y="Percent Cases Last 14 Days", data=x2)
# Out:
# <AxesSubplot:xlabel='Percent Cases Total', ylabel='Percent Cases Last 14 Days'>

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,15)).fit(x2)
visualizer.show()

#Based off the graph the optimal number of clusters is 4
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42).fit(x2)
#y_kmeans = cluster labels 
y_kmeans = kmeans.predict(x2)
y_kmeans = pd.DataFrame(y_kmeans)
Counter(kmeans.labels_)
# Out:
# Counter({1: 61, 3: 111, 0: 172, 2: 7})

# %%
center = kmeans.cluster_centers_
center
# Out:
# array([[0.00388232, 0.00026792],
#        [0.01956115, 0.0004375 ],
#        [0.05147281, 0.00152257],
#        [0.01021211, 0.00026379]])

# %% [markdown]
# ### KNN Model Creation

# %%
# next steps... predict k nearest neighbors
#Reload the main dataframe excluding the y vals columns and use standard scaler on it
x = df.iloc[:, 3:29]
#Scale data since some numbers are extremly large
#from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(x)
x = pd.DataFrame(x)
#Perform PCA to reduce dimensionality
pca = PCA(n_components=2)
pca.fit(x)
x3 = pca.transform(x)

# %%
#Split data into training and testing sets - use 80% as training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x3, y_kmeans, test_size=0.20, random_state=43)
#Find the best performing value of k
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
parameters = {"n_neighbors": range(1, 50)}
gridsearch = GridSearchCV(KNeighborsRegressor(), parameters)
gridsearch.fit(X_train, y_train)

print(gridsearch.best_params_)
#The best number of neighbors on the training set is 47 <- this changes with each run
# Out:
# {'n_neighbors': 19}

# %%
neigh = KNeighborsClassifier(n_neighbors=28)
neigh = neigh.fit(X_train, y_train)
y_pred = neigh.predict(X_test)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
#Visualize the data
from sklearn import datasets, neighbors
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

plot_decision_regions(X_test, y_pred, clf = neigh)
plt.xlabel("X Test Data")
plt.ylabel("Y Predictions")
plt.title("KNN Model Predictions")
plt.show()

# %%
#Evaluate how we did
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.88      0.74        33
#            1       0.62      0.36      0.45        14
#            2       0.00      0.00      0.00         1
#            3       0.56      0.43      0.49        23
#
#     accuracy                           0.62        71
#    macro avg       0.46      0.42      0.42        71
# weighted avg       0.60      0.62      0.59        71
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn import metrics
score = metrics.accuracy_score(y_test, y_pred)
print("Classification Accuracy(Percent of Correct Predictions): ", score*100)
misclass = 1 - metrics.accuracy_score(y_test, y_pred)
print("Misclassification Rate(Percent of Misclassified Predictions): ", misclass*100)

#Stuff below is in the classification report shown above
#sensitivity = metrics.recall_score(y_test, y_pred)
#print("Sensitivity: ", sensitivity)
#precision = metrics.precision_score(y_test, y_pred)
#print("Precision: ", precision)
# Out:
# Classification Accuracy(Percent of Correct Predictions):  61.97183098591549
# Misclassification Rate(Percent of Misclassified Predictions):  38.02816901408451

# %%
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[29  0  0  4]
#  [ 5  5  0  4]
#  [ 0  1  0  0]
#  [11  2  0 10]]

# %% [markdown]
# ### Retry KNN Model with Sequential Feature Selection

# %%
#Retry with Sequential Feature Selection
from sklearn.feature_selection import SequentialFeatureSelector

#Might want to chnage this based off of whatever is the best
neigh = KNeighborsClassifier(n_neighbors=38)
#Number of features to select. For some reason I can't choose more than 1
n_features = 1
sfs = SequentialFeatureSelector(neigh, n_features_to_select = n_features, direction='forward')
sfs.fit(X_test, y_pred)

#Some sort of numpy error for this
#print("Top {} features selected by forward sequential selection:{}".format(n_features, list(X_test.columns[sfs.get_support()])))
# Out:
# SequentialFeatureSelector(estimator=KNeighborsClassifier(n_neighbors=38),
#                           n_features_to_select=1)

# %%
#Try bootstrapping the sample after PCA/standardizing
from sklearn.utils import resample
boot = resample(x3, replace=True, n_samples=351, random_state=1)
print('Bootstrap Sample: %s' % boot)
# Out:
# Bootstrap Sample: [[-8.98508723e-01  2.05822635e-01]
#  [ 2.19734640e+00 -5.07902991e+00]
#  [ 7.89887401e-01  8.67488638e-01]
#  [-9.98541500e-01 -2.52216086e+00]
#  [-1.36574139e+00 -2.49220243e-01]
#  [-5.15665733e-01 -5.22289828e-02]
#  [ 1.96959468e+00  9.23897385e-02]
#  [-4.36739144e-01  2.69385549e-02]
#  [-1.22603827e+00 -1.46826822e+00]
#  [ 8.34918878e-01 -5.65421934e-01]
#  [-5.71186333e-01 -3.25706286e-02]
#  [-6.50797755e-01 -2.72616293e-01]
#  [-9.85939268e-01  1.07561663e-01]
#  [-3.50466977e-01  1.13738615e-01]
#  [-1.38458145e+00  1.05317371e+00]
#  [-1.34931602e+00  3.54613004e+00]
#  [-9.64593841e-01  2.78067462e-01]
#  [ 9.02273068e-01 -1.23755343e+00]
#  [-1.23778705e+00 -5.11247656e-01]
#  [-5.70525183e-01  1.01796848e+00]
#  [-1.26295536e+00  3.86830449e+00]
#  [-1.05393085e+00  2.92408143e+00]
#  [-8.28883790e-01  1.22812118e+00]
#  [ 3.70786406e-01 -1.56837988e+00]
#  [-1.15749008e+00 -2.53610908e-01]
#  [-1.40946583e+00  3.56209013e+00]
#  [-1.48731793e+00  1.91627360e+00]
#  [ 1.70557450e+00 -9.29316936e-01]
#  [-9.45167999e-02 -1.12575867e+00]
#  [-4.19411947e-01  2.88395858e-01]]

# %%
X_train, X_test, y_train, y_test = train_test_split(boot, y_kmeans, test_size=0.20, random_state=42)

parameters = {"n_neighbors": range(1, 50)}
gridsearch = GridSearchCV(KNeighborsRegressor(), parameters)
gridsearch.fit(X_train, y_train)

print(gridsearch.best_params_)
#k = 46 is best <- this will change
# Out:
# {'n_neighbors': 48}

# %%
neigh = KNeighborsClassifier(n_neighbors=49)
neigh.fit(X_train, y_train)
y_pred = neigh.predict(X_test)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
plot_decision_regions(X_test, y_pred, clf = neigh)
plt.xlabel("X Test Data")
plt.ylabel("Y Predictions")
plt.title("KNN Model Predictions")
plt.show()

# %%
#Evaluate how we did
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))

#F1 Score is between 38 and 42 percent. Even worse than before.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.85      0.61        34
#            1       0.00      0.00      0.00        10
#            2       0.00      0.00      0.00         3
#            3       0.40      0.17      0.24        24
#
#     accuracy                           0.46        71
#    macro avg       0.22      0.25      0.21        71
# weighted avg       0.36      0.46      0.37        71
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Correlation Analysis

# %%
X=df.iloc[:, 3:29]
columns=df.iloc[:, 3:29].columns

# %%
X.corr()
# Out:
#                                 Population  Median annual household income  \
# Population                        1.000000                       -0.101065
# Median annual household income   -0.101065                        1.000000
# Residential Tax Rating           -0.089039                        0.037523
# Open Space Tax Rating            -0.015968                        0.054881
# Commercial Tax Rating             0.291461                       -0.116664
# Industrial Tax Rating             0.291461                       -0.116664
# Personal Property Tax Rating      0.291609                       -0.116774
# Residential APV                   0.902282                        0.060176
# Open Space APV                    0.000260                        0.063182
# Commercial APV                    0.894850                       -0.038207
# Industrial APV                    0.316394                        0.008296
# Personal Property APV             0.932170                       -0.058468
# Residential Levy                  0.935915                        0.115577
# Open Space Levy                   0.002251                        0.082540
# Commercial Levy                   0.901882                       -0.051341
# Industrial Levy                   0.443066                       -0.016056
# Personal Property Levy            0.946965                       -0.083475
# Labor Force                       0.996020                       -0.087457
# Employed                          0.995476                       -0.084991
# Unemployed                        0.982218                       -0.178699
# EQV Per Capita                   -0.078095                        0.008300
# Total Revenues                   -0.006555                        0.005880
# Meals Tax Rate                    0.122909                       -0.037785
# Marijuana Tax Rate                0.046108                        0.093862
# Scaled 2019 Bond Rating          -0.262371                       -0.320449
#
#                                 Residential Tax Rating  Open Space Tax Rating  \
# Population                                   -0.089039              -0.015968
# Median annual household income                0.037523               0.054881
# Residential Tax Rating                        1.000000              -0.018633
# Open Space Tax Rating                        -0.018633               1.000000
# Commercial Tax Rating                         0.531321              -0.053424
# Industrial Tax Rating                         0.531321              -0.053424
# Personal Property Tax Rating                  0.531549              -0.053529
# Residential APV                              -0.254981               0.005308
# Open Space APV                               -0.096031               0.563528
# Commercial APV                               -0.120310              -0.015798
# Industrial APV                               -0.150007               0.004957
# Personal Property APV                        -0.123714              -0.007037
# Residential Levy                             -0.158598               0.011012
# Open Space Levy                              -0.032035               0.575026
# Commercial Levy                              -0.090653              -0.018137
# Industrial Levy                              -0.133253               0.000943
# Personal Property Levy                       -0.069985              -0.017544
# Labor Force                                  -0.100294              -0.015933
# Employed                                     -0.100840              -0.015883
# Unemployed                                   -0.075951              -0.017286
# EQV Per Capita                               -0.579976               0.004619
# Total Revenues                                0.025406              -0.008871
# Meals Tax Rate                               -0.038096              -0.011302
# Marijuana Tax Rate                            0.057599               0.025527
# Scaled 2019 Bond Rating                       0.004366              -0.035072
#
#                                 Commercial Tax Rating  Industrial Tax Rating  \
# Population                                   0.291461               0.291461
# Median annual household income              -0.116664              -0.116664
# Residential Tax Rating                       0.531321               0.531321
# Open Space Tax Rating                       -0.053424              -0.053424
# Commercial Tax Rating                        1.000000               1.000000
# Industrial Tax Rating                        1.000000               1.000000
# Personal Property Tax Rating                 0.999994               0.999994
# Residential APV                              0.060733               0.060733
# Open Space APV                              -0.025019              -0.025019
# Commercial APV                               0.084972               0.084972
# Industrial APV                               0.107282               0.107282
# Personal Property APV                        0.147203               0.147203
# Residential Levy                             0.184194               0.184194
# Open Space Levy                              0.023960               0.023960
# Commercial Levy                              0.121081               0.121081
# Industrial Levy                              0.274147               0.274147
# Personal Property Levy                       0.227889               0.227889
# Labor Force                                  0.264474               0.264474
# Employed                                     0.262538               0.262538
# Unemployed                                   0.329282               0.329282
# EQV Per Capita                              -0.444215              -0.444215
# Total Revenues                              -0.017057              -0.017057
# Meals Tax Rate                               0.072926               0.072926
# Marijuana Tax Rate                           0.010113               0.010113
# Scaled 2019 Bond Rating                     -0.205543              -0.205543
#
#                                 Personal Property Tax Rating  Residential APV  \
# Population                                          0.291609         0.902282
# Median annual household income                     -0.116774         0.060176
# Residential Tax Rating                              0.531549        -0.254981
# Open Space Tax Rating                              -0.053529         0.005308
# Commercial Tax Rating                               0.999994         0.060733
# Industrial Tax Rating                               0.999994         0.060733
# Personal Property Tax Rating                        1.000000         0.060788
# Residential APV                                     0.060788         1.000000
# Open Space APV                                     -0.025138         0.072318
# Commercial APV                                      0.085034         0.923182
# Industrial APV                                      0.107321         0.372393
# Personal Property APV                               0.147262         0.927501
# Residential Levy                                    0.184273         0.960896
# Open Space Levy                                     0.023846         0.036218
# Commercial Levy                                     0.121159         0.902868
# Industrial Levy                                     0.274253         0.440836
# Personal Property Levy                              0.227983         0.893373
# Labor Force                                         0.264603         0.920501
# Employed                                            0.262666         0.921847
# Unemployed                                          0.329457         0.837039
# EQV Per Capita                                     -0.444346         0.088891
# Total Revenues                                     -0.017026        -0.009285
# Meals Tax Rate                                      0.072953         0.127769
# Marijuana Tax Rate                                  0.010424         0.100144
# Scaled 2019 Bond Rating                            -0.205274        -0.281344
#
#                                 Open Space APV  Commercial APV  ...  \
# Population                            0.000260        0.894850  ...
# Median annual household income        0.063182       -0.038207  ...
# Residential Tax Rating               -0.096031       -0.120310  ...
# Open Space Tax Rating                 0.563528       -0.015798  ...
# Commercial Tax Rating                -0.025019        0.084972  ...
# Industrial Tax Rating                -0.025019        0.084972  ...
# Personal Property Tax Rating         -0.025138        0.085034  ...
# Residential APV                       0.072318        0.923182  ...
# Open Space APV                        1.000000        0.000687  ...
# Commercial APV                        0.000687        1.000000  ...
# Industrial APV                        0.035662        0.335266  ...
# Personal Property APV                 0.018898        0.982876  ...
# Residential Levy                      0.058027        0.871761  ...
# Open Space Levy                       0.965359       -0.002700  ...
# Commercial Levy                      -0.005057        0.994326  ...
# Industrial Levy                       0.062994        0.403569  ...
# Personal Property Levy                0.006337        0.965021  ...
# Labor Force                          -0.002697        0.919956  ...
# Employed                             -0.002749        0.921406  ...
# Unemployed                           -0.000590        0.832533  ...
# EQV Per Capita                        0.083396        0.006654  ...
# Total Revenues                       -0.004084       -0.005886  ...
# Meals Tax Rate                        0.071405        0.068167  ...
# Marijuana Tax Rate                   -0.004557        0.062494  ...
# Scaled 2019 Bond Rating              -0.032694       -0.165709  ...
#
#                                 Industrial Levy  Personal Property Levy   \
# Population                             0.443066                 0.946965
# Median annual household income        -0.016056                -0.083475
# Residential Tax Rating                -0.133253                -0.069985
# Open Space Tax Rating                  0.000943                -0.017544
# Commercial Tax Rating                  0.274147                 0.227889
# Industrial Tax Rating                  0.274147                 0.227889
# Personal Property Tax Rating           0.274253                 0.227983
# Residential APV                        0.440836                 0.893373
# Open Space APV                         0.062994                 0.006337
# Commercial APV                         0.403569                 0.965021
# Industrial APV                         0.953309                 0.297901
# Personal Property APV                  0.473683                 0.986979
# Residential Levy                       0.393331                 0.885898
# Open Space Levy                        0.076544                 0.009311
# Commercial Levy                        0.346075                 0.975582
# Industrial Levy                        1.000000                 0.418018
# Personal Property Levy                 0.418018                 1.000000
# Labor Force                            0.454728                 0.956059
# Employed                               0.455377                 0.956393
# Unemployed                             0.414133                 0.910052
# EQV Per Capita                        -0.039463                -0.033808
# Total Revenues                        -0.015446                -0.010896
# Meals Tax Rate                         0.095036                 0.077548
# Marijuana Tax Rate                     0.052900                 0.049124
# Scaled 2019 Bond Rating               -0.243378                -0.179685
#
#                                 Labor Force  Employed  Unemployed  \
# Population                         0.996020  0.995476    0.982218
# Median annual household income    -0.087457 -0.084991   -0.178699
# Residential Tax Rating            -0.100294 -0.100840   -0.075951
# Open Space Tax Rating             -0.015933 -0.015883   -0.017286
# Commercial Tax Rating              0.264474  0.262538    0.329282
# Industrial Tax Rating              0.264474  0.262538    0.329282
# Personal Property Tax Rating       0.264603  0.262666    0.329457
# Residential APV                    0.920501  0.921847    0.837039
# Open Space APV                    -0.002697 -0.002749   -0.000590
# Commercial APV                     0.919956  0.921406    0.832533
# Industrial APV                     0.335637  0.336850    0.277633
# Personal Property APV              0.949120  0.949988    0.882923
# Residential Levy                   0.942043  0.942804    0.880167
# Open Space Levy                   -0.000036  0.000045   -0.003120
# Commercial Levy                    0.923702  0.924914    0.845243
# Industrial Levy                    0.454728  0.455377    0.414133
# Personal Property Levy             0.956059  0.956393    0.910052
# Labor Force                        1.000000  0.999977    0.966106
# Employed                           0.999977  1.000000    0.964340
# Unemployed                         0.966106  0.964340    1.000000
# EQV Per Capita                    -0.072860 -0.072520   -0.083324
# Total Revenues                    -0.005694 -0.005756   -0.003115
# Meals Tax Rate                     0.120514  0.120496    0.117004
# Marijuana Tax Rate                 0.052153  0.052647    0.031459
# Scaled 2019 Bond Rating           -0.263628 -0.264097   -0.236556
#
#                                 EQV Per Capita  Total Revenues  \
# Population                           -0.078095       -0.006555
# Median annual household income        0.008300        0.005880
# Residential Tax Rating               -0.579976        0.025406
# Open Space Tax Rating                 0.004619       -0.008871
# Commercial Tax Rating                -0.444215       -0.017057
# Industrial Tax Rating                -0.444215       -0.017057
# Personal Property Tax Rating         -0.444346       -0.017026
# Residential APV                       0.088891       -0.009285
# Open Space APV                        0.083396       -0.004084
# Commercial APV                        0.006654       -0.005886
# Industrial APV                       -0.007250       -0.009681
# Personal Property APV                -0.000095       -0.009113
# Residential Levy                     -0.011794       -0.005301
# Open Space Levy                       0.022250       -0.003735
# Commercial Levy                      -0.009525       -0.006749
# Industrial Levy                      -0.039463       -0.015446
# Personal Property Levy               -0.033808       -0.010896
# Labor Force                          -0.072860       -0.005694
# Employed                             -0.072520       -0.005756
# Unemployed                           -0.083324       -0.003115
# EQV Per Capita                        1.000000       -0.015087
# Total Revenues                       -0.015087        1.000000
# Meals Tax Rate                       -0.087544        0.053705
# Marijuana Tax Rate                   -0.075327        0.063301
# Scaled 2019 Bond Rating               0.070897        0.050890
#
#                                 Meals Tax Rate  Marijuana Tax Rate  \
# Population                            0.122909            0.046108
# Median annual household income       -0.037785            0.093862
# Residential Tax Rating               -0.038096            0.057599
# Open Space Tax Rating                -0.011302            0.025527
# Commercial Tax Rating                 0.072926            0.010113
# Industrial Tax Rating                 0.072926            0.010113
# Personal Property Tax Rating          0.072953            0.010424
# Residential APV                       0.127769            0.100144
# Open Space APV                        0.071405           -0.004557
# Commercial APV                        0.068167            0.062494
# Industrial APV                        0.071687            0.058796
# Personal Property APV                 0.081781            0.063125
# Residential Levy                      0.135743            0.098950
# Open Space Levy                       0.057934           -0.020314
# Commercial Levy                       0.061835            0.052799
# Industrial Levy                       0.095036            0.052900
# Personal Property Levy                0.077548            0.049124
# Labor Force                           0.120514            0.052153
# Employed                              0.120496            0.052647
# Unemployed                            0.117004            0.031459
# EQV Per Capita                       -0.087544           -0.075327
# Total Revenues                        0.053705            0.063301
# Meals Tax Rate                        1.000000            0.208883
# Marijuana Tax Rate                    0.208883            1.000000
# Scaled 2019 Bond Rating              -0.097356            0.001177
#
#                                 Scaled 2019 Bond Rating
# Population                                    -0.262371
# Median annual household income                -0.320449
# Residential Tax Rating                         0.004366
# Open Space Tax Rating                         -0.035072
# Commercial Tax Rating                         -0.205543
# Industrial Tax Rating                         -0.205543
# Personal Property Tax Rating                  -0.205274
# Residential APV                               -0.281344
# Open Space APV                                -0.032694
# Commercial APV                                -0.165709
# Industrial APV                                -0.195560
# Personal Property APV                         -0.187524
# Residential Levy                              -0.333650
# Open Space Levy                               -0.040465
# Commercial Levy                               -0.154661
# Industrial Levy                               -0.243378
# Personal Property Levy                        -0.179685
# Labor Force                                   -0.263628
# Employed                                      -0.264097
# Unemployed                                    -0.236556
# EQV Per Capita                                 0.070897
# Total Revenues                                 0.050890
# Meals Tax Rate                                -0.097356
# Marijuana Tax Rate                             0.001177
# Scaled 2019 Bond Rating                        1.000000
#
# [25 rows x 25 columns]

# %%
# Labor Force, Employed, Unemployed are very highly correlated with Population (>0.95)
# Commercial Tax Rating and Industrial Tax Raring are highly correlated with Personal Propert Tax rating (>0.95))
# commercial Levy is highly correlated with commercial APV (>0.99) and with personal property Levy (>0.95) and Personal Property APV (>0.95)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools import add_constant
vif_x=add_constant(X)
pd.Series([variance_inflation_factor(vif_x.values,i) for i in range(vif_x.shape[1])], index=vif_x.columns)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# C:\Users\joshu\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# const                             7.941352e+01
# Population                        1.026695e+03
# Median annual household income    2.037900e+00
# Residential Tax Rating            2.820089e+00
# Open Space Tax Rating             1.547467e+00
# Commercial Tax Rating             4.503600e+15
# Industrial Tax Rating             4.503600e+15
# Personal Property Tax Rating      8.241730e+04
# Residential APV                   9.821888e+01
# Open Space APV                    2.441207e+01
# Commercial APV                    1.731525e+03
# Industrial APV                    7.005092e+01
# Personal Property APV             3.368592e+02
# Residential Levy                  6.548465e+01
# Open Space Levy                   2.366170e+01
# Commercial Levy                   1.695012e+03
# Industrial Levy                   4.513354e+01
# Personal Property Levy            3.416939e+02
# Labor Force                                inf
# Employed                                   inf
# Unemployed                                 inf
# EQV Per Capita                    1.850559e+00
# Total Revenues                    1.015937e+00
# Meals Tax Rate                    1.126668e+00
# Marijuana Tax Rate                1.131093e+00
# Scaled 2019 Bond Rating           1.446565e+00
# dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools import add_constant
vif_x=add_constant(X)
pd.Series([variance_inflation_factor(vif_x.values,i) for i in range(vif_x.shape[1])], index=vif_x.columns)
# Out:
# const                             7.941352e+01
# Population                        1.026695e+03
# Median annual household income    2.037900e+00
# Residential Tax Rating            2.820089e+00
# Open Space Tax Rating             1.547467e+00
# Commercial Tax Rating             4.503600e+15
# Industrial Tax Rating             4.503600e+15
# Personal Property Tax Rating      8.241730e+04
# Residential APV                   9.821888e+01
# Open Space APV                    2.441207e+01
# Commercial APV                    1.731525e+03
# Industrial APV                    7.005092e+01
# Personal Property APV             3.368592e+02
# Residential Levy                  6.548465e+01
# Open Space Levy                   2.366170e+01
# Commercial Levy                   1.695012e+03
# Industrial Levy                   4.513354e+01
# Personal Property Levy            3.416939e+02
# Labor Force                                inf
# Employed                                   inf
# Unemployed                                 inf
# EQV Per Capita                    1.850559e+00
# Total Revenues                    1.015937e+00
# Meals Tax Rate                    1.126668e+00
# Marijuana Tax Rate                1.131093e+00
# Scaled 2019 Bond Rating           1.446565e+00
# dtype: float64

# %%
vif_x=add_constant(X[columns])
pd.Series([variance_inflation_factor(vif_x.values,i) for i in range(vif_x.shape[1])], index=vif_x.columns)
# Out:
# const                             7.941352e+01
# Population                        1.026695e+03
# Median annual household income    2.037900e+00
# Residential Tax Rating            2.820089e+00
# Open Space Tax Rating             1.547467e+00
# Commercial Tax Rating             4.503600e+15
# Industrial Tax Rating             4.503600e+15
# Personal Property Tax Rating      8.241730e+04
# Residential APV                   9.821888e+01
# Open Space APV                    2.441207e+01
# Commercial APV                    1.731525e+03
# Industrial APV                    7.005092e+01
# Personal Property APV             3.368592e+02
# Residential Levy                  6.548465e+01
# Open Space Levy                   2.366170e+01
# Commercial Levy                   1.695012e+03
# Industrial Levy                   4.513354e+01
# Personal Property Levy            3.416939e+02
# Labor Force                                inf
# Employed                                   inf
# Unemployed                                 inf
# EQV Per Capita                    1.850559e+00
# Total Revenues                    1.015937e+00
# Meals Tax Rate                    1.126668e+00
# Marijuana Tax Rate                1.131093e+00
# Scaled 2019 Bond Rating           1.446565e+00
# dtype: float64

# %%
# 2 classes, 1 being improved vs avg, 0 being didn't improve
target=[]
total=list(df['Percent Cases Total'])
last_2_weeks=list(df['Percent Cases Last 14 Days'])
for i in range(351):
    if(total[i]/12<last_2_weeks[i]):
        target.append(1)
    else:
        target.append(0)

# %%
y=target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X[columns], y, test_size=0.20, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.9295774647887324

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(min_samples_leaf=6, # vary max_depth between 3 and 6
n_estimators=200, random_state=42)

clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.9154929577464789

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_train,y_train)
neigh.score(X_test,y_test)
# Out:
# 0.8591549295774648

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier(max_depth=2)
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.9295774647887324

# %%
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score

loo=LeaveOneOut()

# %%
model=LogisticRegression()
scores = cross_val_score(model, X[columns], y, scoring='accuracy',
                         cv=loo, n_jobs=-1)
scores.mean()
# Out:
# 0.8803418803418803

# %%
model=DecisionTreeClassifier(max_depth=2)
scores = cross_val_score(model, X[columns], y, scoring='accuracy',
                         cv=loo, n_jobs=-1)
scores.mean()
# Out:
# 0.8746438746438746

# %%
model=neigh
scores = cross_val_score(model, X[columns], y, scoring='accuracy',
                         cv=loo, n_jobs=-1)
scores.mean()
# Out:
# 0.8290598290598291

# %%
model=RandomForestClassifier(min_samples_leaf=6, # vary max_depth between 3 and 6
                                n_estimators=200, random_state=42)
scores = cross_val_score(model, X[columns], y, scoring='accuracy',
                         cv=loo, n_jobs=-1)
scores.mean()
# Out:
# 0.8774928774928775

# %% [markdown]
# ### Decision Trees

# %%
# using 4 classes here
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42).fit(x2)
#y_kmeans = cluster labels 
y_kmeans = kmeans.predict(x2)
y_kmeans = pd.DataFrame(y_kmeans)
Counter(kmeans.labels_)
# Out:
# Counter({1: 61, 3: 111, 0: 172, 2: 7})

# %%
from sklearn import tree
from sklearn.metrics import classification_report, confusion_matrix
X_train, X_test, y_train, y_test = train_test_split(x, y_kmeans, random_state=43, test_size=0.10)
dt_X_train, dt_X_test = scaler.inverse_transform(X_train), scaler.inverse_transform(X_test)
print(dt_X_train.shape)
dt_clf = tree.DecisionTreeClassifier(max_depth=5)
dt_clf.fit(dt_X_train, y_train)
dt_clf2 = tree.DecisionTreeClassifier(max_depth=2)
dt_clf2.fit(dt_X_train, y_train)
print(dt_clf.score(dt_X_test, y_test), dt_clf2.score(dt_X_test, y_test))
dt_clf.score(dt_X_train, y_train)
# Out:
# (315, 25)
# 0.6388888888888888 0.6666666666666666
# 0.8285714285714286

# %%
print(classification_report(dt_clf.predict(dt_X_test), y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        20
#            1       0.29      0.50      0.36         4
#            3       0.57      0.33      0.42        12
#
#     accuracy                           0.64        36
#    macro avg       0.54      0.56      0.53        36
# weighted avg       0.65      0.64      0.63        36

# %%
import graphviz
import pydot

dot_data = tree.export_graphviz(dt_clf2, out_file=None,
                               feature_names=df.iloc[:, 3:29].keys(),
                               filled=True, rounded=True,
                               special_characters=True)
pydot.graph_from_dot_data(dot_data)[0].write_pdf('dt_clf4.pdf')
graphviz.Source(dot_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1922         try:
# -> 1923             stdout_data, stderr_data, process = call_graphviz(
#    1924                 program=prog,
#
# ~\anaconda3\lib\site-packages\pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     131
# --> 132     process = subprocess.Popen(
#     133         program_with_args,
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19560/3270349426.py in <module>
#       6                                filled=True, rounded=True,
#       7                                special_characters=True)
# ----> 8 pydot.graph_from_dot_data(dot_data)[0].write_pdf('dt_clf4.pdf')
#       9 graphviz.Source(dot_data)
#
# ~\anaconda3\lib\site-packages\pydot.py in new_method(path, f, prog, encoding)
#    1741                     encoding=None):
#    1742                 """Refer to docstring of method `write.`"""
# -> 1743                 self.write(
#    1744                     path, format=f, prog=prog,
#    1745                     encoding=encoding)
#
# ~\anaconda3\lib\site-packages\pydot.py in write(self, path, prog, format, encoding)
#    1826                 f.write(s)
#    1827         else:
# -> 1828             s = self.create(prog, format, encoding=encoding)
#    1829             with io.open(path, mode='wb') as f:
#    1830                 f.write(s)
#
# ~\anaconda3\lib\site-packages\pydot.py in create(self, prog, format, encoding)
#    1931                 args[1] = '"{prog}" not found in path.'.format(
#    1932                     prog=prog)
# -> 1933                 raise OSError(*args)
#    1934             else:
#    1935                 raise
#
# FileNotFoundError: [WinError 2] "dot" not found in path.

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
rf_clf = RandomForestClassifier(min_samples_leaf=6, # vary max_depth between 3 and 6
                                n_estimators=200, random_state=42)
rf_clf.fit(dt_X_train, y_train)
print(rf_clf.score(dt_X_test, y_test))
rf_clf.score(dt_X_train, y_train)
y_pred = rf_clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# C:\Users\joshu\AppData\Local\Temp/ipykernel_19560/3079597809.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_clf.fit(dt_X_train, y_train)
# 0.6666666666666666
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76        22
#            1       0.00      0.00      0.00         7
#            3       0.00      0.00      0.00         7
#
#     accuracy                           0.61        36
#    macro avg       0.20      0.33      0.25        36
# weighted avg       0.37      0.61      0.46        36
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### LOOCV For All Models

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
# we were able to get a 74% accuracy using the random forest method
# because of severe class imbalance we are trying leave one out cross validation to trade
# an increase in variance for a reduction in bias
loo = LeaveOneOut()

# perform LOO CV
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #criterion='entropy',
    rf_clf = RandomForestClassifier(min_samples_leaf=6, # vary max_depth between 3 and 6
                                    n_estimators=200, random_state=42)
    #print(i)
    rf_clf.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += rf_clf.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += rf_clf.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
#print(rf_clf.score(X_train, y_train), rf_clf.score(X_test, y_test))
# Out:
# 0.6524216524216508 0.8164509564509578

# %%
ab_clf = AdaBoostClassifier(base_estimator=tree.DecisionTreeClassifier(max_depth=2), n_estimators=50)
# perform LOO CV
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #print(i)
    ab_clf.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += ab_clf.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += ab_clf.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
# Out:
# 0.578347578347578 0.6684086284086294

# %%
dt_clf = tree.DecisionTreeClassifier(max_depth=2)
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #print(i)
    dt_clf.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += dt_clf.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += dt_clf.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
# Out:
# 0.5897435897435892 0.6730077330077331

# %%
neigh = KNeighborsClassifier(weights='distance', n_neighbors=18)
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #print(i)
    neigh.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += neigh.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += neigh.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
# Out:
# 0.6438746438746424 0.9999999999999927

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression(random_state=42)
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #print(i)
    lr_clf.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += lr_clf.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += lr_clf.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
# Out:
# 0.649572649572648 0.7033536833536842

# %%
# now for the 2 class case
from sklearn.cluster import KMeans
#K-means++ uses seeding technique for centroid initialization better than random initialization
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=1).fit(x)
#Check prediction on x data - cluster labels
y_kmeans = kmeans.predict(x)
y_kmeans = pd.DataFrame(y_kmeans)
y_kmeans
#prediction = pd.DataFrame(y_kmeans)
#prediction.head(10)
# Out:
#      0
# 0    3
# 1    3
# 2    3
# 3    0
# 4    0
# ..  ..
# 346  0
# 347  0
# 348  3
# 349  3
# 350  3
#
# [351 rows x 1 columns]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneOut
# we were able to get a 74% accuracy using the random forest method
# because of severe class imbalance we are trying leave one out cross validation to trade
# an increase in variance for a reduction in bias
loo = LeaveOneOut()
# perform LOO CV
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #criterion='entropy',
    rf_clf = RandomForestClassifier(min_samples_leaf=6, # vary max_depth between 3 and 6
                                    n_estimators=200, random_state=42)
    #print(i)
    rf_clf.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += rf_clf.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += rf_clf.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
ab_clf = AdaBoostClassifier(base_estimator=tree.DecisionTreeClassifier(max_depth=2), n_estimators=50)
# perform LOO CV
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #print(i)
    ab_clf.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += ab_clf.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += ab_clf.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
dt_clf = tree.DecisionTreeClassifier(max_depth=2)
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #print(i)
    dt_clf.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += dt_clf.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += dt_clf.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
neigh = KNeighborsClassifier(weights='distance', n_neighbors=18)
splits = loo.split(x)
avg_score = 0
avg_train_score = 0
x_loo = np.array(x)
y_loo = np.array(y_kmeans)
i = 1
for train_splits, test_splits in splits:
    #print(i)
    neigh.fit(x_loo[train_splits], y_loo[train_splits].ravel())
    avg_train_score += neigh.score(x_loo[train_splits], y_loo[train_splits])/351
    avg_score += neigh.score(x_loo[test_splits], y_loo[test_splits])/351
    i += 1
print(avg_score, avg_train_score)
# Out:
# 0.9686609686609619 0.9856084656084628
# 0.9544159544159478 0.9881969881969824
# 0.9430199430199366 0.9770777370777336
# 0.9430199430199366 0.9999999999999927

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.decomposition import PCA
import seaborn as sns

#Reload the main dataframe excluding the y vals columns and use standard scaler on it
x = df.iloc[:, 3:29]

#Scale data since some numbers are extremly large
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scalex = scaler.fit_transform(x)
scalex = pd.DataFrame(scalex)

#PCA to help reduce dimensionality
pca = PCA(n_components=25)
pca.fit(x)
pca_x = pca.transform(x)

# %%
#Split data into training and testing sets - use 90% as training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y_kmeans[0], test_size=0.10,random_state=1)
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(pca_x, y_kmeans[0], test_size=0.1)
X_train_n, X_test_n, y_train_n, y_test_n = train_test_split(scalex, y_kmeans[0], test_size=0.1)

# %%
param_grid_lr = {
    'max_iter': [200, 500, 1000],                      
    'solver': ['liblinear','saga']
}

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
logreg=LogisticRegression(penalty='l1')
logreg_cv=GridSearchCV(logreg,param_grid_lr,cv=10)
logreg_cv.fit(X_train,y_train)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# GridSearchCV(cv=10, estimator=LogisticRegression(penalty='l1'),
#              param_grid={'max_iter': [200, 500, 1000],
#                          'solver': ['liblinear', 'saga']})

# %%
print(logreg_cv.best_params_)
print(logreg_cv.best_score_)
# Out:
# {'max_iter': 200, 'solver': 'liblinear'}
# 0.9493951612903228

# %% [markdown]
# ### Results without L1

# %%
# no preprocs
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0,solver = 'liblinear',max_iter = 500).fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
clf.coef_
# Out:
# array([[ 3.36489089e-07, -1.15945980e-05, -2.02738615e-09,
#          3.09962893e-11, -1.32819834e-09, -1.32819834e-09,
#         -1.32975379e-09,  9.11246478e-10,  2.04236011e-06,
#          1.22800181e-08, -3.31683596e-08, -2.19869378e-07,
#          2.27769361e-08,  3.53180400e-08, -7.10196864e-07,
#          3.16753072e-06,  9.36437556e-06,  2.07170009e-07,
#          2.01278579e-07,  5.89143030e-09, -1.63035091e-05,
#         -6.47083724e-09, -8.67066034e-16, -4.86049855e-13,
#         -9.12342645e-10],
#        [-7.34642143e-12, -2.83237563e-09, -6.25721291e-13,
#         -8.99874747e-16, -6.70858052e-13, -6.70858052e-13,
#         -6.70853193e-13, -8.65012338e-08, -1.17917319e-10,
#          1.86840282e-07, -4.79857770e-07,  1.16134791e-07,
#         -4.15653028e-08, -1.77216754e-12,  1.14135772e-08,
#         -9.83954963e-09,  5.24191891e-09, -6.92885316e-12,
#         -6.80296218e-12, -1.25890980e-13, -1.01857589e-08,
#         -3.10790678e-07, -6.49764865e-17, -1.75278031e-16,
#         -3.67694619e-13],
#        [-8.36768664e-12, -2.22730297e-09, -3.10684278e-13,
#         -4.32565884e-16, -3.20547150e-13, -3.20547150e-13,
#         -3.20545046e-13, -8.40592597e-08, -5.40498539e-11,
#          1.12425988e-07,  2.49152968e-07, -3.55878613e-07,
#         -1.37324626e-08, -8.12975005e-13,  1.72923591e-08,
#          8.25449690e-09, -1.70103097e-09, -3.37249220e-12,
#         -3.21255255e-12, -1.59939651e-13, -1.20635836e-08,
#         -3.44729771e-07, -4.01443379e-17, -1.01673383e-16,
#         -3.00626201e-13],
#        [ 8.28251834e-07,  2.24552357e-05,  3.93641364e-09,
#         -5.88329987e-11,  2.58694701e-09,  2.58694701e-09,
#          2.58688792e-09, -1.13378389e-09, -2.21708364e-06,
#          5.75237420e-09, -6.98605364e-08,  3.54748839e-07,
#         -3.20440777e-09, -3.69664250e-08, -6.88183985e-07,
#          2.60549108e-06, -1.66159300e-05,  5.14003438e-07,
#          4.99585182e-07,  1.44182559e-08,  2.58949143e-05,
#          2.18523667e-09, -2.57288522e-14, -7.26690780e-13,
#          1.66916505e-09]])

# %%
x.columns[13]
# Out:
# 'Open Space Levy'

# %%
#normalized 
from sklearn.linear_model import LogisticRegression
clf2 = LogisticRegression(random_state=0,solver = 'liblinear',max_iter = 500).fit(X_train_n, y_train_n)
clf2.score(X_test_n,y_test_n)
# Out:
# 1.0

# %%
clf2.coef_
# Out:
# array([[ 6.47622463e-01, -5.31894344e-01, -7.70042869e-01,
#          1.65518979e-01,  1.62032287e+00,  1.62032287e+00,
#          1.61599753e+00,  1.45031588e-01,  7.81954057e-02,
#         -1.08223911e+00, -2.71730881e-01, -8.36308139e-01,
#          1.27052922e+00,  3.25711285e-02, -1.03814640e+00,
#          5.53147179e-01, -7.02894253e-01,  4.61778599e-01,
#          4.54217196e-01,  7.34773360e-01,  5.43194591e-01,
#         -9.76086846e-02,  6.96368944e-01,  8.74891668e-02,
#         -2.81187072e-01],
#        [ 4.12757523e-03,  1.92973046e-02,  1.85599860e-02,
#         -5.19440594e-02, -4.26060139e-03, -4.26060139e-03,
#         -4.52004494e-03,  2.41986404e-02,  9.23589129e-02,
#          1.64038967e-01, -6.54093307e-02,  1.10241074e-01,
#         -1.11419085e-02,  1.17157499e-01,  1.77662400e-01,
#         -2.34711577e-02,  1.04353194e-01,  3.36491627e-02,
#          3.52035966e-02, -2.69418809e-02,  9.59366892e-04,
#         -4.24422631e-03, -1.91806181e-02, -2.95346062e-03,
#          4.38621884e-03],
#        [-2.17963787e-02,  5.38645569e-03,  1.67982895e-02,
#         -5.86683149e-02, -1.16595284e-02, -1.16595284e-02,
#         -1.18415715e-02,  2.07605253e-02,  9.69769707e-02,
#          3.37538499e-02,  3.13816022e-01,  7.36893118e-03,
#         -4.29077754e-02,  1.18574846e-01, -6.09754005e-03,
#          2.08168947e-01, -3.10677550e-02, -1.25042117e-02,
#         -1.17508376e-02, -4.08686462e-02,  2.88754084e-03,
#         -8.42240117e-04, -9.67990350e-03,  3.01793719e-03,
#         -1.40064174e-02],
#        [-7.80334913e-01,  5.23660636e-01,  3.97514937e-01,
#         -1.41951775e-01, -1.60286824e+00, -1.60286824e+00,
#         -1.60515845e+00, -5.03698877e-01, -1.13254953e-01,
#         -3.79582707e-01, -4.62224167e-01, -1.49163658e-01,
#         -7.96803781e-01, -7.02253538e-02, -3.97239149e-01,
#         -8.08519576e-01, -3.09514457e-01, -7.22513304e-01,
#         -7.21686070e-01, -7.29016888e-01, -4.81722727e-01,
#          8.80062921e-02, -6.82994300e-01, -1.90461062e-01,
#          9.10360107e-02]])

# %%
# pca 
from sklearn.linear_model import LogisticRegression
clf3 = LogisticRegression(random_state=0,solver = 'liblinear',max_iter = 500).fit(X_train_p, y_train_p)
clf3.score(X_test_p,y_test_p)
# Out:
# 0.9444444444444444

# %% [markdown]
# ### Results with L1

# %%
# no preprocs
from sklearn.linear_model import LogisticRegression
clf4 = LogisticRegression(random_state=0,solver = 'liblinear',max_iter = 1000,penalty = 'l1').fit(X_train, y_train)
clf4.score(X_test,y_test)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 0.9722222222222222

# %%
#normalized 
from sklearn.linear_model import LogisticRegression
clf5 = LogisticRegression(random_state=1,solver = 'liblinear',max_iter = 500, C=1000,penalty ='l1').fit(X_train_n, y_train_n)
clf5.score(X_test_n,y_test_n)
# Out:
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
clf6 = LogisticRegression(random_state=1,solver = 'saga',penalty ='elasticnet', max_iter = 900,l1_ratio = 0.1).fit(X_train_p, y_train_p)
clf6.score(X_test_p,y_test_p)
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.8333333333333334

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            3       1.00      1.00      1.00        28
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
#
# [[ 8  0]
#  [ 0 28]]

# %%
test_acc =[]
train_acc = []

test_acc_n = []
test_acc_pca = []

for i in range(351):
    
    X_test = x.iloc[[i]]
    y_test = y_kmeans.iloc[[i]]
    X_train = x.drop(i)
    y_train = y_kmeans.drop(i)
    
    X_test_n = scalex.iloc[[i]]
    y_test_n = y_kmeans.iloc[[i]]
    X_train_n = scalex.drop(i)
    y_train_n = y_kmeans.drop(i)
    
    X_test_p = pd.DataFrame(pca_x).iloc[[i]]
    y_test_p = y_kmeans.iloc[[i]]
    X_train_p = pd.DataFrame(pca_x).drop(i)
    y_train_p = y_kmeans.drop(i)
    
    
    clf = LogisticRegression(random_state=2,solver = 'liblinear',max_iter = 500).fit(X_train, y_train)
    clf2 = LogisticRegression(random_state=2,solver = 'liblinear',max_iter = 500).fit(X_train_n, y_train_n)
    clf3 = LogisticRegression(random_state=2,solver = 'liblinear',max_iter = 500).fit(X_train_p, y_train_p)
    
    #clf4 = LogisticRegression(random_state=2,solver = 'saga',penalty ='elasticnet', max_iter = 600, l1_ratio =0.01).fit(X_train_p, y_train_p)
    #clf5 = LogisticRegression(random_state=2,solver = 'saga',penalty ='elasticnet', max_iter = 600, l1_ratio =1e-5).fit(X_train_p, y_train_p)
    
    test_acc.append(clf.score(X_test,y_test))
    test_acc_n.append(clf2.score(X_test_n,y_test_n))
    test_acc_pca.append(clf3.score(X_test_p,y_test_p))
    #test_acc.append(clf5.score(X_test_p,y_test_p))
    #test_acc_n.append(clf5.score(X_train_p,y_train_p))
# Out:
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\joshu\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
#In order - Test Accuracy, Normalized Test Accuracy, PCA Test Accuracy

print(sum(test_acc)/351)
print(sum(test_acc_n)/351)
print(sum(test_acc_pca)/351)
# Out:
# 0.9601139601139601
# 0.98005698005698
# 0.9287749287749287
